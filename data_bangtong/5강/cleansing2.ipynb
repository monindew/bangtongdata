# %%
import pandas as pd

df = pd.read_csv("patient.csv")

# %%
df
# Out:
#    Patient_ID  Test_Time_Sec   Test_Date  Blood_Pressure  Max_Blood_Pressure  \
# 0          11            272  2023-12-29            81.0               108.0
# 1          12            147  2023-12-28           110.0               109.0
# 2          12            217  2023-12-27             NaN                 NaN
# 3          13            292  2023-12-26            96.0                 NaN
# 4          14            423  2023-12-25             NaN                93.0
# 5          15            351  2023-12-24            84.0                87.0
# 6          16            295  2023-12-23             NaN                 NaN
# 7          17            459  2023-12-22            72.0                95.0
# 8          18            109  2023-12-21           118.0               190.0
# 9          19            311  2023-12-20            61.0                78.0
#
#    Weight_kg
# 0  54.356465
# 1  51.010920
# 2  91.630992
# 3        NaN
# 4        NaN
# 5  98.930917
# 6        NaN
# ...
